# %% [markdown]
# This program extracts 1000 artists from Spotify and runs graph embedding over the artist graph.

# %%
import artists_embedding_final02 as em

# %%
n_artists = 1000
n_dims = 3

# %% [markdown]
# The bfs() function builds the artist graph using the breadth first search traversal algorithm. This function need not be run if graph is already built.

# %%
em.bfs(n_artists)
# Out:
# Retrieving data from Spotify took 164.9525933265686 seconds.

# %% [markdown]
# The get_embeddings() function does the following,
#
# 1. Runs a graph embedding algorithm, called DeepWalk over the artist graph.
# 2. Constructs a dataframe, where each row represents an artist and each column represents one dimention in the embedding space.
# 3. Runs k-means algorithm, for k=10.
# 4. Plots the graph.

# %%
em.embedding_and_clustering(n_artists,n_dims)
# Out:
# Graph embedding took 43.76730227470398 seconds.
